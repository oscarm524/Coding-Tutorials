# %%
import pandas as pd; pd.options.display.max_columns = None

# Read the CSV file
df = pd.read_csv('dmc2006_train.csv')
df.head()
# Out:
#    auct_id                            item_leaf_category_name  \
# 0        1  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Mini ...
# 1        3  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Mini ...
# 2        4  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Mini ...
# 3        5  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Mini ...
# 4        6  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Mini ...
#
#                                        listing_title  \
# 0  Apple iPod mini 4 GB 2. Gen. 2005 silber blau ...
# 1  APPLE iPod mini Musicplayer 4GB Mac/Win USB 2....
# 2  Apple iPOD Mini Silber NEUWARE mit Rechnung/Ga...
# 3  Apple i-Pod mini 4GB BLUE  org. verpackt +Rech...
# 4                          Apple iPod mini 4 GB Rosa
#
#                                     listing_subtitle listing_start_date  \
# 0                                                NaN            6/24/05
# 1                                                NaN            8/13/05
# 2                                                NaN             9/8/05
# 3  Neuwertig +Garantie ¸ber Original-Rechnung (Me...           10/14/05
# 4                                                NaN            9/18/05
#
#   listing_end_date  listing_durtn_days  listing_type_code  \
# 0          11/3/05                 132                  7
# 1         10/11/05                  59                  7
# 2         10/23/05                  45                  7
# 3         10/24/05                  10                  1
# 4         10/13/05                  25                  7
#
#    feedback_score_at_listing_time  start_price  buy_it_now_price  \
# 0                            2182        195.0                 0
# 1                           10604        185.0                 0
# 2                              72        195.0                 0
# 3                               2         85.0                 0
# 4                             136        199.0                 0
#
#   buy_it_now_listed_flag bold_fee_flag featured_fee_flag  \
# 0                      N             N                 N
# 1                      N             N                 N
# 2                      N             N                 N
# 3                      N             Y                 N
# 4                      N             N                 N
#
#   category_featured_fee_flag gallery_fee_flag gallery_featured_fee_flag  \
# 0                          N                Y                         N
# 1                          N                N                         N
# 2                          N                Y                         N
# 3                          N                Y                         N
# 4                          N                N                         N
#
#   ipix_featured_fee_flag reserve_fee_flag highlight_fee_flag  \
# 0                      N                N                  N
# 1                      N                N                  N
# 2                      N                N                  N
# 3                      Y                N                  N
# 4                      N                N                  N
#
#   schedule_fee_flag border_fee_flag  qty_available_per_listing    gms  \
# 0                 N               N                         48  195.0
# 1                 N               N                          2  185.0
# 2                 N               N                          2  195.0
# 3                 Y               Y                          1  172.0
# 4                 N               N                          1  199.0
#
#    category_avg_gms  gms_greater_avg
# 0           167.977                1
# 1           167.977                1
# 2           167.977                1
# 3           161.512                1
# 4           173.450                1

# %%
df.describe(include='all')
# Out:
#              auct_id                            item_leaf_category_name  \
# count    7998.000000                                               7998
# unique           NaN                                                 15
# top              NaN  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Nano ...
# freq             NaN                                               1797
# mean     7987.342086                                                NaN
# std      4607.328549                                                NaN
# min         1.000000                                                NaN
# 25%      4004.500000                                                NaN
# 50%      7990.500000                                                NaN
# 75%     12003.500000                                                NaN
# max     16000.000000                                                NaN
#
#                                             listing_title listing_subtitle  \
# count                                                7998             1050
# unique                                               6279              885
# top     Apple - iPod  NANO 2GB  **schwarz** NEU/OVP/Re...           #NAME?
# freq                                                  275               17
# mean                                                  NaN              NaN
# std                                                   NaN              NaN
# min                                                   NaN              NaN
# 25%                                                   NaN              NaN
# 50%                                                   NaN              NaN
# 75%                                                   NaN              NaN
# max                                                   NaN              NaN
#
#        listing_start_date listing_end_date  listing_durtn_days  \
# count                7998             7998         7998.000000
# unique                189              174                 NaN
# top              12/11/05         12/18/05                 NaN
# freq                  109              179                 NaN
# mean                  NaN              NaN            5.015379
# std                   NaN              NaN            4.481509
# min                   NaN              NaN            0.000000
# 25%                   NaN              NaN            3.000000
# 50%                   NaN              NaN            5.000000
# 75%                   NaN              NaN            7.000000
# max                   NaN              NaN          175.000000
#
#         listing_type_code  feedback_score_at_listing_time  start_price  \
# count         7998.000000                     7998.000000  7998.000000
# unique                NaN                             NaN          NaN
# top                   NaN                             NaN          NaN
# freq                  NaN                             NaN          NaN
# mean             1.864841                      759.148412    45.572354
# std              2.471974                     2596.453340    82.163806
# min              1.000000                       -1.000000     1.000000
# 25%              1.000000                       25.000000     1.000000
# 50%              1.000000                       81.000000     1.000000
# 75%              1.000000                      260.750000    50.000000
# max              9.000000                    26883.000000   414.000000
#
#         buy_it_now_price buy_it_now_listed_flag bold_fee_flag  \
# count        7998.000000                   7998          7998
# unique               NaN                      2             2
# top                  NaN                      N             N
# freq                 NaN                   6272          6831
# mean           45.479495                    NaN           NaN
# std            90.214508                    NaN           NaN
# min             0.000000                    NaN           NaN
# 25%             0.000000                    NaN           NaN
# 50%             0.000000                    NaN           NaN
# 75%             0.000000                    NaN           NaN
# max           500.000000                    NaN           NaN
#
#        featured_fee_flag category_featured_fee_flag gallery_fee_flag  \
# count               7998                       7998             7998
# unique                 1                          2                2
# top                    N                          N                Y
# freq                7998                       7947             4127
# mean                 NaN                        NaN              NaN
# std                  NaN                        NaN              NaN
# min                  NaN                        NaN              NaN
# 25%                  NaN                        NaN              NaN
# 50%                  NaN                        NaN              NaN
# 75%                  NaN                        NaN              NaN
# max                  NaN                        NaN              NaN
#
#        gallery_featured_fee_flag ipix_featured_fee_flag reserve_fee_flag  \
# count                       7998                   7998             7998
# unique                         2                      2                1
# top                            N                      N                N
# freq                        7981                   5583             7998
# mean                         NaN                    NaN              NaN
# std                          NaN                    NaN              NaN
# min                          NaN                    NaN              NaN
# 25%                          NaN                    NaN              NaN
# 50%                          NaN                    NaN              NaN
# 75%                          NaN                    NaN              NaN
# max                          NaN                    NaN              NaN
#
#        highlight_fee_flag schedule_fee_flag border_fee_flag  \
# count                7998              7998            7998
# unique                  2                 2               2
# top                     N                 N               N
# freq                 7498              6299            7583
# mean                  NaN               NaN             NaN
# std                   NaN               NaN             NaN
# min                   NaN               NaN             NaN
# 25%                   NaN               NaN             NaN
# 50%                   NaN               NaN             NaN
# 75%                   NaN               NaN             NaN
# max                   NaN               NaN             NaN
#
#         qty_available_per_listing          gms  category_avg_gms  \
# count                 7998.000000  7880.000000       7998.000000
# unique                        NaN          NaN               NaN
# top                           NaN          NaN               NaN
# freq                          NaN          NaN               NaN
# mean                     1.206802   196.956565        197.217064
# std                      2.628894    46.795330         29.281467
# min                      1.000000     1.000000        158.578000
# 25%                      1.000000   165.072500        167.977000
# 50%                      1.000000   187.750000        197.862000
# 75%                      1.000000   223.000000        207.358000
# max                    150.000000   601.510000        263.459000
#
#         gms_greater_avg
# count       7998.000000
# unique              NaN
# top                 NaN
# freq                NaN
# mean           0.475119
# std            0.499412
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            1.000000
# max            1.000000

# %%
# Reporting the percentage of missing values in each column
100*df.isna().sum() / len(df)
# Out:
# auct_id                            0.000000
# item_leaf_category_name            0.000000
# listing_title                      0.000000
# listing_subtitle                  86.871718
# listing_start_date                 0.000000
# listing_end_date                   0.000000
# listing_durtn_days                 0.000000
# listing_type_code                  0.000000
# feedback_score_at_listing_time     0.000000
# start_price                        0.000000
# buy_it_now_price                   0.000000
# buy_it_now_listed_flag             0.000000
# bold_fee_flag                      0.000000
# featured_fee_flag                  0.000000
# category_featured_fee_flag         0.000000
# gallery_fee_flag                   0.000000
# gallery_featured_fee_flag          0.000000
# ipix_featured_fee_flag             0.000000
# reserve_fee_flag                   0.000000
# highlight_fee_flag                 0.000000
# schedule_fee_flag                  0.000000
# border_fee_flag                    0.000000
# qty_available_per_listing          0.000000
# gms                                1.475369
# category_avg_gms                   0.000000
# gms_greater_avg                    0.000000
# dtype: float64

# %%
# Reporting duplicated rows
df.duplicated().sum()
# Out:
# 0

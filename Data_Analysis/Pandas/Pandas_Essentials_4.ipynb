# %%
import pandas as pd; pd.options.display.max_columns = None

# Read the CSV file
df = pd.read_csv('dmc2006_train.csv')
df.head()
# Out:
#    auct_id                            item_leaf_category_name  \
# 0        1  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Mini ...
# 1        3  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Mini ...
# 2        4  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Mini ...
# 3        5  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Mini ...
# 4        6  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Mini ...
#
#                                        listing_title  \
# 0  Apple iPod mini 4 GB 2. Gen. 2005 silber blau ...
# 1  APPLE iPod mini Musicplayer 4GB Mac/Win USB 2....
# 2  Apple iPOD Mini Silber NEUWARE mit Rechnung/Ga...
# 3  Apple i-Pod mini 4GB BLUE  org. verpackt +Rech...
# 4                          Apple iPod mini 4 GB Rosa
#
#                                     listing_subtitle listing_start_date  \
# 0                                                NaN            6/24/05
# 1                                                NaN            8/13/05
# ...

# %%
# Accessing the 'start_price' column
df["start_price"]
# Out:
# 0       195.00
# 1       185.00
# 2       195.00
# 3        85.00
# 4       199.00
#          ...
# 7993      1.99
# 7994      1.99
# 7995      1.99
# 7996    100.00
# 7997      1.00
# Name: start_price, Length: 7998, dtype: float64

# %%
# Second approach to access the 'start_price' column
df.start_price
# Out:
# 0       195.00
# 1       185.00
# 2       195.00
# 3        85.00
# 4       199.00
#          ...
# 7993      1.99
# 7994      1.99
# 7995      1.99
# 7996    100.00
# 7997      1.00
# Name: start_price, Length: 7998, dtype: float64

# %%
# Computing the mean of the 'start_price' column
df["start_price"].mean()
# Out:
# 45.572354338584645

# %%
# Creating a new column
df["start_price_squared"] = df["start_price"]**2
df.head()
# Out:
#    auct_id                            item_leaf_category_name  \
# 0        1  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Mini ...
# 1        3  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Mini ...
# 2        4  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Mini ...
# 3        5  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Mini ...
# 4        6  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Mini ...
#
#                                        listing_title  \
# 0  Apple iPod mini 4 GB 2. Gen. 2005 silber blau ...
# 1  APPLE iPod mini Musicplayer 4GB Mac/Win USB 2....
# 2  Apple iPOD Mini Silber NEUWARE mit Rechnung/Ga...
# 3  Apple i-Pod mini 4GB BLUE  org. verpackt +Rech...
# 4                          Apple iPod mini 4 GB Rosa
#
#                                     listing_subtitle listing_start_date  \
# 0                                                NaN            6/24/05
# 1                                                NaN            8/13/05
# ...

# %%
# Creating a constant column
df["constant"] = 10
df.head()
# Out:
#    auct_id                            item_leaf_category_name  \
# 0        1  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Mini ...
# 1        3  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Mini ...
# 2        4  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Mini ...
# 3        5  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Mini ...
# 4        6  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Mini ...
#
#                                        listing_title  \
# 0  Apple iPod mini 4 GB 2. Gen. 2005 silber blau ...
# 1  APPLE iPod mini Musicplayer 4GB Mac/Win USB 2....
# 2  Apple iPOD Mini Silber NEUWARE mit Rechnung/Ga...
# 3  Apple i-Pod mini 4GB BLUE  org. verpackt +Rech...
# 4                          Apple iPod mini 4 GB Rosa
#
#                                     listing_subtitle listing_start_date  \
# 0                                                NaN            6/24/05
# 1                                                NaN            8/13/05
# ...

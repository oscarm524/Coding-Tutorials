# %%
import pandas as pd; pd.options.display.max_columns = None

# Read the CSV file
df = pd.read_csv('dmc2006_train.csv')
df.head()
# Out:
#    auct_id                            item_leaf_category_name  \
# 0        1  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Mini ...
# 1        3  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Mini ...
# 2        4  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Mini ...
# 3        5  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Mini ...
# 4        6  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Mini ...
#
#                                        listing_title  \
# 0  Apple iPod mini 4 GB 2. Gen. 2005 silber blau ...
# 1  APPLE iPod mini Musicplayer 4GB Mac/Win USB 2....
# 2  Apple iPOD Mini Silber NEUWARE mit Rechnung/Ga...
# 3  Apple i-Pod mini 4GB BLUE  org. verpackt +Rech...
# 4                          Apple iPod mini 4 GB Rosa
#
#                                     listing_subtitle listing_start_date  \
# 0                                                NaN            6/24/05
# 1                                                NaN            8/13/05
# ...

# %%
df["start_price"].describe()
# Out:
# count    7998.000000
# mean       45.572354
# std        82.163806
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%        50.000000
# max       414.000000
# Name: start_price, dtype: float64

# %%
# Selecting items with start_price greater than 300
df[df["start_price"]>300].head()
# Out:
#       auct_id                    item_leaf_category_name  \
# 304       599  Audio & Hi-Fi:MP3-Player:Apple iPod:40 GB
# 407       799  Audio & Hi-Fi:MP3-Player:Apple iPod:40 GB
# 820      1645  Audio & Hi-Fi:MP3-Player:Apple iPod:30 GB
# 1862     3729  Audio & Hi-Fi:MP3-Player:Apple iPod:40 GB
# 2273     4580  Audio & Hi-Fi:MP3-Player:Apple iPod:40 GB
#
#                                           listing_title  \
# 304   Apple iPod Photo / Farbdisplay 40 GB / 5. GEN....
# 407         Apple iPod PHOTO 40GB *Topmodel,5.Gen.,OVP*
# 820      APPLE IPOD VIDEO 30GB *NEU* Orignal + Rechnung
# 1862                    APPLE I-POD 40GB , Zubehˆr, OVP
# 2273             Apple iPod Video 60 GB schwarz --NEU--
#
#                         listing_subtitle listing_start_date listing_end_date  \
# 304                                  NaN           10/13/05         10/16/05
# 407   +viel Zubehˆr im Wert von ca. 100ˇ           10/17/05         10/27/05
# ...

# %%
# Selecting items with start_price greater than 300
df.query("start_price>300").head()
# Out:
#       auct_id                    item_leaf_category_name  \
# 304       599  Audio & Hi-Fi:MP3-Player:Apple iPod:40 GB
# 407       799  Audio & Hi-Fi:MP3-Player:Apple iPod:40 GB
# 820      1645  Audio & Hi-Fi:MP3-Player:Apple iPod:30 GB
# 1862     3729  Audio & Hi-Fi:MP3-Player:Apple iPod:40 GB
# 2273     4580  Audio & Hi-Fi:MP3-Player:Apple iPod:40 GB
#
#                                           listing_title  \
# 304   Apple iPod Photo / Farbdisplay 40 GB / 5. GEN....
# 407         Apple iPod PHOTO 40GB *Topmodel,5.Gen.,OVP*
# 820      APPLE IPOD VIDEO 30GB *NEU* Orignal + Rechnung
# 1862                    APPLE I-POD 40GB , Zubehˆr, OVP
# 2273             Apple iPod Video 60 GB schwarz --NEU--
#
#                         listing_subtitle listing_start_date listing_end_date  \
# 304                                  NaN           10/13/05         10/16/05
# 407   +viel Zubehˆr im Wert von ca. 100ˇ           10/17/05         10/27/05
# ...

# %%
# Selecting items with start_price greater than 300 and gms_greater_avg equals 1
df[(df["start_price"]>300) & (df["gms_greater_avg"]==1)].head()
# Out:
#       auct_id                    item_leaf_category_name  \
# 304       599  Audio & Hi-Fi:MP3-Player:Apple iPod:40 GB
# 820      1645  Audio & Hi-Fi:MP3-Player:Apple iPod:30 GB
# 1862     3729  Audio & Hi-Fi:MP3-Player:Apple iPod:40 GB
# 2273     4580  Audio & Hi-Fi:MP3-Player:Apple iPod:40 GB
# 2360     4752  Audio & Hi-Fi:MP3-Player:Apple iPod:40 GB
#
#                                           listing_title listing_subtitle  \
# 304   Apple iPod Photo / Farbdisplay 40 GB / 5. GEN....              NaN
# 820      APPLE IPOD VIDEO 30GB *NEU* Orignal + Rechnung              NaN
# 1862                    APPLE I-POD 40GB , Zubehˆr, OVP              NaN
# 2273             Apple iPod Video 60 GB schwarz --NEU--              NaN
# 2360                                    Apple iPod 40GB              NaN
#
#      listing_start_date listing_end_date  listing_durtn_days  \
# 304            10/13/05         10/16/05                   3
# ...

# %%
# Selecting items with start_price greater than 300 and gms_greater_avg equals 1
df.query("start_price>300 and gms_greater_avg==1").head()
# Out:
#       auct_id                    item_leaf_category_name  \
# 304       599  Audio & Hi-Fi:MP3-Player:Apple iPod:40 GB
# 820      1645  Audio & Hi-Fi:MP3-Player:Apple iPod:30 GB
# 1862     3729  Audio & Hi-Fi:MP3-Player:Apple iPod:40 GB
# 2273     4580  Audio & Hi-Fi:MP3-Player:Apple iPod:40 GB
# 2360     4752  Audio & Hi-Fi:MP3-Player:Apple iPod:40 GB
#
#                                           listing_title listing_subtitle  \
# 304   Apple iPod Photo / Farbdisplay 40 GB / 5. GEN....              NaN
# 820      APPLE IPOD VIDEO 30GB *NEU* Orignal + Rechnung              NaN
# 1862                    APPLE I-POD 40GB , Zubehˆr, OVP              NaN
# 2273             Apple iPod Video 60 GB schwarz --NEU--              NaN
# 2360                                    Apple iPod 40GB              NaN
#
#      listing_start_date listing_end_date  listing_durtn_days  \
# 304            10/13/05         10/16/05                   3
# ...

# %%
import pandas as pd 

# Read the CSV file into a DataFrame
df = pd.read_csv("dmc2006_train.csv")

# %%
# Printing the first 5 rows of the DataFrame
df.head()
# Out:
#    auct_id                            item_leaf_category_name  \
# 0        1  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Mini ...
# 1        3  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Mini ...
# 2        4  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Mini ...
# 3        5  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Mini ...
# 4        6  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Mini ...
#
#                                        listing_title  \
# 0  Apple iPod mini 4 GB 2. Gen. 2005 silber blau ...
# 1  APPLE iPod mini Musicplayer 4GB Mac/Win USB 2....
# 2  Apple iPOD Mini Silber NEUWARE mit Rechnung/Ga...
# 3  Apple i-Pod mini 4GB BLUE  org. verpackt +Rech...
# 4                          Apple iPod mini 4 GB Rosa
#
#                                     listing_subtitle listing_start_date  \
# 0                                                NaN            6/24/05
# 1                                                NaN            8/13/05
# 2                                                NaN             9/8/05
# 3  Neuwertig +Garantie ¸ber Original-Rechnung (Me...           10/14/05
# 4                                                NaN            9/18/05
#
#   listing_end_date  listing_durtn_days  listing_type_code  \
# 0          11/3/05                 132                  7
# 1         10/11/05                  59                  7
# 2         10/23/05                  45                  7
# 3         10/24/05                  10                  1
# 4         10/13/05                  25                  7
#
#    feedback_score_at_listing_time  start_price  ...  \
# 0                            2182        195.0  ...
# 1                           10604        185.0  ...
# 2                              72        195.0  ...
# 3                               2         85.0  ...
# 4                             136        199.0  ...
#
#    gallery_featured_fee_flag ipix_featured_fee_flag reserve_fee_flag  \
# 0                          N                      N                N
# 1                          N                      N                N
# 2                          N                      N                N
# 3                          N                      Y                N
# 4                          N                      N                N
#
#   highlight_fee_flag schedule_fee_flag border_fee_flag  \
# 0                  N                 N               N
# 1                  N                 N               N
# 2                  N                 N               N
# 3                  N                 Y               Y
# 4                  N                 N               N
#
#   qty_available_per_listing    gms category_avg_gms gms_greater_avg
# 0                        48  195.0          167.977               1
# 1                         2  185.0          167.977               1
# 2                         2  195.0          167.977               1
# 3                         1  172.0          161.512               1
# 4                         1  199.0          173.450               1
#
# [5 rows x 26 columns]

# %%
# Printing the last 5 rows of the DataFrame
df.tail()
# Out:
#       auct_id                            item_leaf_category_name  \
# 7993    15995  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Nano ...
# 7994    15996  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Nano ...
# 7995    15997  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Nano ...
# 7996    15998          Audio & Hi-Fi:MP3-Player:Apple iPod:40 GB
# 7997    16000  Audio & Hi-Fi:MP3-Player:Apple iPod:iPod Nano ...
#
#                                           listing_title listing_subtitle  \
# 7993  Apple - iPod  NANO 4GB(4 GB) schwarz /NEU/OVP/...              NaN
# 7994  Apple - iPod  NANO 4GB(4 GB) schwarz /NEU/OVP/...              NaN
# 7995  Apple - iPod  NANO 4GB(4 GB) schwarz /NEU/OVP/...              NaN
# 7996         iPod 4.Generation 40GB Defekt fuer bastler              NaN
# 7997  Apple - iPod NANO 2GB **schwarz** NEU mit Rech...              NaN
#
#      listing_start_date listing_end_date  listing_durtn_days  \
# 7993            3/18/06          3/19/06                   1
# 7994            3/18/06          3/21/06                   3
# 7995            3/18/06          3/23/06                   5
# 7996            3/19/06          3/22/06                   3
# 7997            3/19/06          3/22/06                   3
#
#       listing_type_code  feedback_score_at_listing_time  start_price  ...  \
# 7993                  1                            2849         1.99  ...
# 7994                  1                            2849         1.99  ...
# 7995                  1                            2849         1.99  ...
# 7996                  1                              53       100.00  ...
# 7997                  1                             160         1.00  ...
#
#       gallery_featured_fee_flag ipix_featured_fee_flag reserve_fee_flag  \
# 7993                          N                      N                N
# 7994                          N                      N                N
# 7995                          N                      N                N
# 7996                          N                      Y                N
# 7997                          N                      N                N
#
#      highlight_fee_flag schedule_fee_flag border_fee_flag  \
# 7993                  N                 N               N
# 7994                  N                 N               N
# 7995                  N                 N               N
# 7996                  N                 Y               N
# 7997                  N                 N               N
#
#      qty_available_per_listing     gms category_avg_gms gms_greater_avg
# 7993                         1  213.00          197.862               1
# 7994                         1  225.00          197.862               1
# 7995                         1  222.22          197.862               1
# 7996                         1  180.00          221.153               0
# 7997                         1  165.01          166.481               0
#
# [5 rows x 26 columns]

# %%
# Printing the shape of the DataFrame
df.shape
# Out:
# (7998, 26)

# %%
# Printing the info of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7998 entries, 0 to 7997
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   auct_id                         7998 non-null   int64
#  1   item_leaf_category_name         7998 non-null   object
#  2   listing_title                   7998 non-null   object
#  3   listing_subtitle                1050 non-null   object
#  4   listing_start_date              7998 non-null   object
#  5   listing_end_date                7998 non-null   object
#  6   listing_durtn_days              7998 non-null   int64
#  7   listing_type_code               7998 non-null   int64
#  8   feedback_score_at_listing_time  7998 non-null   int64
#  9   start_price                     7998 non-null   float64
#  10  buy_it_now_price                7998 non-null   int64
#  11  buy_it_now_listed_flag          7998 non-null   object
#  12  bold_fee_flag                   7998 non-null   object
#  13  featured_fee_flag               7998 non-null   object
#  14  category_featured_fee_flag      7998 non-null   object
#  15  gallery_fee_flag                7998 non-null   object
#  16  gallery_featured_fee_flag       7998 non-null   object
#  17  ipix_featured_fee_flag          7998 non-null   object
#  18  reserve_fee_flag                7998 non-null   object
#  19  highlight_fee_flag              7998 non-null   object
#  20  schedule_fee_flag               7998 non-null   object
#  21  border_fee_flag                 7998 non-null   object
#  22  qty_available_per_listing       7998 non-null   int64
#  23  gms                             7880 non-null   float64
#  24  category_avg_gms                7998 non-null   float64
#  25  gms_greater_avg                 7998 non-null   int64
# dtypes: float64(3), int64(7), object(16)
# memory usage: 1.6+ MB
